# %%
# Importing necessary modules
from user_posting_emulation import AWSDBConnector

# Initialize the RDS connector and load credentials from YAML
source_yaml = 'db_creds.yaml'
connector_rds = AWSDBConnector(source_yaml)
connector_rds.read_db_creds(source_yaml)
print("RDS connector initialized and credentials loaded.")

# Example of listing the database tables (optional)
engine_rds = connector_rds.create_db_connector()
tables = connector_rds.list_db_tables(engine_rds)

# For stream connectors (assuming you have a separate stream connector in user_posting_emulation.py)
stream_connector_rds = AWSDBConnector(source_yaml)
stream_connector_rds.read_db_creds(source_yaml)
print("Streaming connector initialized and credentials loaded.")
# Out:
# Credentials loaded successfully!!
# Credentials loaded successfully!!
# RDS connector initialized and credentials loaded.
# Tables in the database: ['geolocation_data', 'pinterest_data', 'temp_geolocation_data', 'temp_user_data', 'user_data']
# Credentials loaded successfully!!
# Credentials loaded successfully!!
# Streaming connector initialized and credentials loaded.

# %%
## Initialize and return the SQLAlchemy database engine

engine_rds = connector_rds.create_db_connector()

## Reading the data from the RDS database

connector_tables_rds = connector_rds.list_db_tables(engine_rds)
print("Tables in the database:", connector_tables_rds)
# Out:
# Tables in the database: ['geolocation_data', 'pinterest_data', 'temp_geolocation_data', 'temp_user_data', 'user_data']
# Tables in the database: ['geolocation_data', 'pinterest_data', 'temp_geolocation_data', 'temp_user_data', 'user_data']

# %%
## Printing the tables: pin_result, geo_result and user_result.
connector_rds.run_infinite_post_data_loop_method(engine_rds)
# Out:
# {'index': 7528, 'unique_id': 'fbe53c66-3442-4773-b19e-d3ec6f54dddf', 'title': 'No Title Data Available', 'description': 'No description available Story format', 'poster_name': 'User Info Error', 'follower_count': 'User Info Error', 'tag_list': 'N,o, ,T,a,g,s, ,A,v,a,i,l,a,b,l,e', 'is_image_or_video': 'multi-video(story page format)', 'image_src': 'Image src error.', 'downloaded': 0, 'save_location': 'Local save in /data/mens-fashion', 'category': 'mens-fashion'}
# {'ind': 7528, 'timestamp': datetime.datetime(2020, 8, 28, 3, 52, 47), 'latitude': -89.9787, 'longitude': -173.293, 'country': 'Albania'}
# {'ind': 7528, 'first_name': 'Abigail', 'last_name': 'Ali', 'age': 20, 'date_joined': datetime.datetime(2015, 10, 24, 11, 23, 51)}
# Response status for 0afff86fcd1b.pin: 504
# Response status for 0afff86fcd1b.geo: 504
# Response status for 0afff86fcd1b.user: 504
# ...

# %%
# Initialize and return the SQLAlchemy database engine
stream_engine_rds = stream_connector_rds.create_db_connector()

# Listing the tables in the database
stream_connector_tables_rds = stream_connector_rds.list_db_tables(stream_engine_rds)
print("Tables in the database:", stream_connector_tables_rds)
# Out:
# Tables in the database: ['geolocation_data', 'pinterest_data', 'temp_geolocation_data', 'temp_user_data', 'user_data']
# Tables in the database: ['geolocation_data', 'pinterest_data', 'temp_geolocation_data', 'temp_user_data', 'user_data']

# %%
stream_connector_rds.run_infinite_post_data_loop_method(stream_engine_rds)
# Out:
# {'index': 5069, 'unique_id': 'b75b6f87-deb3-444f-b29e-ce9161b2df49', 'title': 'The Vault: Curated & Refined Wedding Inspiration', 'description': 'Sacramento California Wedding 2 Chic Events & Design Jodi Yorston Photography Wilson Vineyards Barn Miosa Couture Yellow Barn Vineyard Outdoor Candles DIY', 'poster_name': 'Style Me Pretty', 'follower_count': '6M', 'tag_list': '60th Anniversary Parties,Anniversary Decorations,Golden Anniversary,25th Wedding Anniversary,Anniversary Pictures,Anniversary Ideas,Birthday Decorations,Event Planning Design,Event Design', 'is_image_or_video': 'image', 'image_src': 'https://i.pinimg.com/originals/7e/45/90/7e45905fefa36347e83333fd6d091140.jpg', 'downloaded': 1, 'save_location': 'Local save in /data/event-planning', 'category': 'event-planning'}
# {'ind': 5069, 'timestamp': datetime.datetime(2021, 3, 20, 9, 32, 44), 'latitude': -63.0063, 'longitude': -157.474, 'country': 'Azerbaijan'}
# ...
